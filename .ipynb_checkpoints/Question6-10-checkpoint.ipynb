# %% [markdown]
# # Question 6
# Create a line plot showing the number of marriages and divorces per capita in the
# U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
marriages = pd.read_csv("./us-marriages-divorces-1867-2014.csv")
marriages.head()

killings = pd.read_csv("./actor_kill_counts.csv")
killings.head()

roman_emperor = pd.read_csv("./roman-emperor-reigns.csv")
roman_emperor.head()

arcade = pd.read_csv("./arcade-revenue-vs-cs-doctorates.csv")
arcade.head()
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948

# %%
plt.figure(figsize=(10,5))
plt.plot(marriages['Year'], marriages["Marriages_per_1000"], label='Marriages per 1000 people')
plt.plot(marriages['Year'], marriages["Divorces_per_1000"], label='Divorces per 1000 people')

# label and title
plt.xlabel('Year')
plt.ylabel('Count per 1000 people')
plt.title('Marriages and Divorces per 1000 people in US (1867 -2014)')

plt.legend()

plt.show()

# %% [markdown]
# # Question 7
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
filtered_data = marriages[marriages['Year'].isin([1900, 1950, 2000])]

position = np.arange(len(filtered_data['Year']))
bar_width = 0.35

plt.figure(figsize=(10,6))

# marriages
plt.bar(position - bar_width/2, filtered_data['Marriages_per_1000'], bar_width, label='Marriages per 1000 people')
# divorces
plt.bar(position + bar_width/2, filtered_data['Divorces_per_1000'], bar_width, label='Divorces per 1000 people')

# label and title
plt.xlabel('Year')
plt.ylabel('Count per 1000 people')
plt.title('Comparison of Marriages and Divorces per 1000 people in the U.S. (1900, 1950, 2000)')

plt.legend()
plt.xticks(position, filtered_data['Year'])
plt.show()

# %% [markdown]
# # Question 8
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
sorted_data = killings.sort_values('Count',  ascending=False)

plt.figure(figsize=(10,6))
plt.barh(sorted_data['Actor'], sorted_data['Count'])

# label and title
plt.xlabel('Kill Count')
plt.ylabel('Actor')
plt.title('Deadliest Actors in Hollywood')

for index,  value in enumerate(sorted_data['Count']):
    plt.text(value, index, str(value))
    
plt.gca().invert_yaxis()

plt.show()

# %% [markdown]
# # Question 9
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the
# percentage breakdown of the categories.

# %%
roman_emperor['Assassinated'] = roman_emperor['Cause_of_Death'].apply(lambda x: 'Assassinated' if 'assassinated' in x.lower() else 'Other')

category_counts = roman_emperor['Assassinated'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)

plt.axis('equal')

# title
plt.title('Fraction of Roman Emperors Assassinated')

plt.show()

# %% [markdown]
# # Question 10
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Total Arcade Revenue (billions)', y='Computer Science Doctorates Awarded (US)', hue='Year', data=arcade, palette='viridis')

# labels and title
plt.xlabel('Total Arcade Revenue (billions)')
plt.ylabel('Computer Science Doctorates Awarded (US)')
plt.title('Arcade Revenue vs Computer Science PhDs (2000 - 2009)')

plt.show()
